# %%
import pandas as pd

# %%
# create dataframe to store district data
district_data = pd.read_csv('dime_recipients_1979_2024.csv')


# isolates years 2002-2022
after_2002 = district_data['fecyear'] >= 2002
before_2022 = district_data['fecyear'] <= 2022
district_data = district_data[after_2002 & before_2022]
# Out:
# /var/folders/11/1zlp690171z58pnrzbnr1s380000gn/T/ipykernel_1114/113295295.py:2: DtypeWarning: Columns (10,12,15,16,17,41,43,44,45,47,49,50,54,55,58,59,60,61,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   district_data = pd.read_csv('dime_recipients_1979_2024.csv')

# %%
# isolates House candidates
house_candidates = district_data['seat'] == 'federal:house'
district_data = district_data[house_candidates]

# checks that House candidates were selected
district_data['seat'].unique()
# Out:
# array(['federal:house'], dtype=object)

# %%
# isolating statutory candidates for the current cycle
statutory_curr_cycle = district_data['fec.cand.status'] == 'C'

district_data = district_data[statutory_curr_cycle]

# checks that statutory candidates for current cycle were selected
# print(district_data['fec.cand.status'].unique())

district_data
# Out:
#       election  cycle  fecyear  bonica.rid    bonica.cid                name  \
# 268     fd2002   2002   2002.0      cand53  1.056417e+08    conyers, john jr
# 269     fd2004   2004   2004.0      cand53  1.056417e+08    conyers, john jr
# 270     fd2006   2006   2006.0      cand53  1.056417e+08    conyers, john jr
# 272     fd2008   2008   2008.0      cand53  1.056417e+08    conyers, john jr
# 273     fd2010   2010   2010.0      cand53  1.056417e+08    conyers, john jr
# ...        ...    ...      ...         ...           ...                 ...
# 72450   fd2022   2022   2022.0    cand1082  5.000000e+15           chu, judy
# 72451   fd2022   2022   2022.0  cand223228  4.623034e+09        schiff, adam
# 72452   fd2022   2022   2022.0    cand1085  5.302098e+09     garamendi, john
# 73123   fd2022   2022   2022.0    cand1035  5.593459e+09  grayson, alan mark
# 77766   fd2024   2024   2022.0   cand40926  4.101328e+09           chen, jay
#
#            lname     ffname fname mname  ...     FEC.ID        NID  \
# 268      conyers       john  john   NaN  ...  C00409797  N00004029
# 269      conyers       john  john   NaN  ...  C00409797  N00004029
# 270      conyers       john  john   NaN  ...  C00409797  N00004029
# 272      conyers       john  john   NaN  ...  C00409797  N00004029
# 273      conyers       john  john   NaN  ...  C00409797  N00004029
# ...          ...        ...   ...   ...  ...        ...        ...
# 72450        chu       judy  judy   NaN  ...  C00458125  N00030600
# 72451     schiff       adam  adam   NaN  ...  C00343871  N00009585
# 72452  garamendi       john  john   NaN  ...  C00462697  N00030856
# 73123    grayson  alan mark  alan  mark  ...  C00424713  N00028418
# 77766       chen        jay   jay   NaN  ...  C00665695  N00034000
#
#       before.switch.ICPSR after.switch.ICPSR party.orig nimsp.party  \
# 268                   NaN                NaN      100.0         NaN
# 269                   NaN                NaN      100.0         NaN
# 270                   NaN                NaN      100.0         NaN
# 272                   NaN                NaN      100.0         NaN
# 273                   NaN                NaN      100.0         NaN
# ...                   ...                ...        ...         ...
# 72450                 NaN                NaN      100.0         NaN
# 72451                 NaN                NaN      100.0         NaN
# 72452                 NaN                NaN      100.0         NaN
# 73123                 NaN                NaN      100.0         NaN
# 77766                 NaN                NaN        100         NaN
#
#       nimsp.candidate.ICO.code nimsp.district nimsp.office  \
# 268                        NaN            NaN          NaN
# 269                        NaN            NaN          NaN
# 270                        NaN            NaN          NaN
# 272                        NaN            NaN          NaN
# 273                        NaN            NaN          NaN
# ...                        ...            ...          ...
# 72450                      NaN            NaN          NaN
# 72451                      NaN            NaN          NaN
# 72452                      NaN            NaN          NaN
# 73123                      NaN            NaN          NaN
# 77766                      NaN            NaN          NaN
#
#        nimsp.candidate.status
# 268                       NaN
# 269                       NaN
# 270                       NaN
# 272                       NaN
# 273                       NaN
# ...                       ...
# 72450                     NaN
# 72451                     NaN
# 72452                     NaN
# 73123                     NaN
# 77766                     NaN
#
# [15867 rows x 64 columns]

# %%
#dropping observations with no district

has_district = (district_data['district'].isnull())==False

district_data = district_data[has_district]

#ensures that every candidate has a district
#print(district_data['district'].notnull().unique()) 

district_data['ico.status']
# Out:
# 268      I
# 269      I
# 270      I
# 272      I
# 273      I
#         ..
# 72450    I
# 72451    I
# 72452    I
# 73123    O
# 77766    C
# Name: ico.status, Length: 15863, dtype: object

# %%
#dropping observations for Alaska, DC, Hawaii, Guam, American Samoa, Virigin Islands, Puerto Rico
excluded_regions = district_data['state'].isin(['AK','DC','HI','AS','VI','PR'])

included_regions = ~excluded_regions

district_data = district_data[included_regions]

#ensures excluded districts were properly excluded
#print(district_data['state'].isin(['AK','DC','HI','AS','VI','PR']).unique)

# %%
# isolated data based on district, year, state, and incumbents. created separate series counting amount of candidates to avoid double counting
grouped_districts = district_data.groupby(['district','fecyear','state','ico.status'])['name'].nunique().reset_index(name='num_candidates')
#print(grouped_districts)

#represents total_incumbents per district and year
total_incumbents = grouped_districts[['district','fecyear','num_candidates','ico.status']]
total_incumbents = total_incumbents[ total_incumbents['ico.status'] == 'I']
#print(total_incumbents['ico.status'].unique())
total_incumbents = total_incumbents.groupby(['fecyear','district'])['num_candidates'].sum().reset_index(name='total_incumbents')
print(total_incumbents.columns)
# renames 'fecyear' series to 'year'
grouped_districts = grouped_districts.rename(columns={'fecyear': 'year'})
total_incumbents = total_incumbents.rename(columns={'fecyear': 'year'})

# assigns designation for zero, one, or multiple incumbents

grouped_districts['zero_incumbs']= grouped_districts.apply(lambda x: x['ico.status']!= 'I', axis =1)

grouped_districts['one_incumb']= grouped_districts.apply(lambda x: x['num_candidates'] == 1 and x['ico.status']== 'I', axis =1)

grouped_districts['multiple_incumbs']= grouped_districts.apply(lambda x: x['num_candidates'] >=2 and x['ico.status']== 'I', axis =1)



# copies grouped_districts such that num_candidates can be accessed while correctly displaying state-district-year level data


grouped_districts_copy = pd.DataFrame()
grouped_districts_copy = grouped_districts

grouped_districts = grouped_districts.drop('num_candidates', axis=1)

print(total_incumbents.columns)
# Out:
# Index(['fecyear', 'district', 'total_incumbents'], dtype='object')
# Index(['year', 'district', 'total_incumbents'], dtype='object')

# %%
print(total_incumbents.columns)


# Start with the original DataFrame containing 'year' and 'num_candidates'
incumbents_per_year = grouped_districts_copy[['year', 'num_candidates', 'ico.status']]
print(incumbents_per_year)


print(total_incumbents.columns)
total_incumbents = total_incumbents.groupby('year')['total_incumbents'].sum().reset_index(name='total_incumbents')

# amount/proportion of districts with zero incumbents per year
zero_incumb = incumbents_per_year.groupby('year').apply(lambda row: ((row['ico.status']!= 'I') ).sum()).reset_index(name='zero_incumb')

# amount/proportion of districts with one incumbent per year
one_incumb = incumbents_per_year.groupby('year').apply(lambda row: ( (row['num_candidates']==1) & (row['ico.status']== 'I') ).sum()).reset_index(name='one_incumb')
print(one_incumb.head())


# amount/proportion of districts with multiple incumbents per year
multiple_incumb = incumbents_per_year.groupby('year').apply(lambda row: ( (row['num_candidates']>=2) & (row['ico.status']== 'I') ).sum()).reset_index(name='multiple_incumb')




# merge results
incumbents_per_year = zero_incumb.merge(one_incumb, on='year', how='left')
incumbents_per_year = incumbents_per_year.merge(multiple_incumb, on='year', how='left')
incumbents_per_year = incumbents_per_year.merge(total_incumbents, on='year', how='left')

incumbents_per_year['share_zero_incumb'] = incumbents_per_year['zero_incumb'] / total_incumbents['total_incumbents']
incumbents_per_year['share_one_incumb'] = incumbents_per_year['one_incumb'] / total_incumbents['total_incumbents']
incumbents_per_year['share_multiple_incumb'] = incumbents_per_year['multiple_incumb'] / total_incumbents['total_incumbents']

incumbents_per_year
# Out:
# Index(['year', 'total_incumbents'], dtype='object')
#         year  num_candidates ico.status
# 0     2002.0               6          O
# 1     2004.0               1          C
# 2     2004.0               1          I
# 3     2006.0               1          C
# 4     2008.0               1          C
# ...      ...             ...        ...
# 8698  2018.0               1          I
# 8699  2020.0               3          C
# 8700  2020.0               1          I
# 8701  2022.0               6          C
# 8702  2022.0               1          I
#
# [8703 rows x 3 columns]
# Index(['year', 'total_incumbents'], dtype='object')
#      year  one_incumb
# 0  2002.0         347
# 1  2004.0         362
# 2  2006.0         367
# 3  2008.0         412
# 4  2010.0         410
# /var/folders/11/1zlp690171z58pnrzbnr1s380000gn/T/ipykernel_1114/853753215.py:13: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   zero_incumb = incumbents_per_year.groupby('year').apply(lambda row: ((row['ico.status']!= 'I') ).sum()).reset_index(name='zero_incumb')
# /var/folders/11/1zlp690171z58pnrzbnr1s380000gn/T/ipykernel_1114/853753215.py:16: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   one_incumb = incumbents_per_year.groupby('year').apply(lambda row: ( (row['num_candidates']==1) & (row['ico.status']== 'I') ).sum()).reset_index(name='one_incumb')
# /var/folders/11/1zlp690171z58pnrzbnr1s380000gn/T/ipykernel_1114/853753215.py:21: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   multiple_incumb = incumbents_per_year.groupby('year').apply(lambda row: ( (row['num_candidates']>=2) & (row['ico.status']== 'I') ).sum()).reset_index(name='multiple_incumb')
#       year  zero_incumb  one_incumb  multiple_incumb  total_incumbents  \
# 0   2002.0          312         347               15               377
# 1   2004.0          338         362                3               368
# 2   2006.0          346         367               22               412
# 3   2008.0          390         412               10               432
# 4   2010.0          393         410                6               422
# 5   2012.0          413         373               28               430
# 6   2014.0          359         412                4               420
# 7   2016.0          380         421                0               421
# 8   2018.0          452         415                4               423
# 9   2020.0          446         414               11               436
# 10  2022.0          442         373               23               422
#
#     share_zero_incumb  share_one_incumb  share_multiple_incumb
# 0            0.827586          0.920424               0.039788
# 1            0.918478          0.983696               0.008152
# 2            0.839806          0.890777               0.053398
# 3            0.902778          0.953704               0.023148
# 4            0.931280          0.971564               0.014218
# 5            0.960465          0.867442               0.065116
# 6            0.854762          0.980952               0.009524
# 7            0.902613          1.000000               0.000000
# 8            1.068558          0.981087               0.009456
# 9            1.022936          0.949541               0.025229
# 10           1.047393          0.883886               0.054502
